# %% [markdown]
# ## Week 5 - Practice Quiz: Selecting eigenvectors by inspection

# %% [markdown]
# <br/>**1.**
# Recall that for a linear transformation, an eigenvector is a vector which, after applying the transformation, stays in the same span. In the following questions, you will try to geometrically see which vectors of a linear transformation are eigenvectors.
#
# In the following diagram, the dark green vector is given by
# $\begin{bmatrix}
# 1 \\
# 0 \\
# \end{bmatrix}$, the purple vector by
# $\begin{bmatrix}
# 1 \\
# 1 \\
# \end{bmatrix}$ and the brown vector by
# $\begin{bmatrix}
# 0 \\
# 1 \\
# \end{bmatrix}$
#
#
# The transformation $T =
# \begin{bmatrix}
# 2 & 0 \\
# 0 & 2 \\
# \end{bmatrix}$  is applied, which sends the three vectors to the light green vector
# $\begin{bmatrix}
# 2 \\
# 0 \\
# \end{bmatrix}$, the magenta vector
# $\begin{bmatrix}
# 2 \\
# 2 \\
# \end{bmatrix}$ and the orange vector
# $\begin{bmatrix}
# 0 \\
# 2 \\
# \end{bmatrix}$, respectively.
#
#
# ![picture alt](https://i.ibb.co/QQh18WF/Z-1t-R-Pv-Eeecp-Qo-q-ZJ4-g-c4d0e4a759d0a182d396003a5808e5d3-D.png)
#
# Which of the three original vectors are eigenvectors of the linear transformation $T$?
#
# **$\begin{bmatrix}
# 1 \\
# 0 \\
# \end{bmatrix}$**
#
# **$\begin{bmatrix}
# 1 \\
# 1 \\
# \end{bmatrix}$**
#
# **$\begin{bmatrix}
# 0 \\
# 1 \\
# \end{bmatrix}$**

# %% [markdown]
# <br/>**2.**
# Recall that for a linear transformation, an eigenvector is a vector which, after applying the transformation, stays in the same span. In the following questions, you will try to geometrically see which vectors of a linear transformation are eigenvectors.
#
# In the following diagram, the dark green vector is given by
# $\begin{bmatrix}
# 1 \\
# 0 \\
# \end{bmatrix}$, the purple vector by
# $\begin{bmatrix}
# 1 \\
# 1 \\
# \end{bmatrix}$ and the brown vector by
# $\begin{bmatrix}
# 0 \\
# 1 \\
# \end{bmatrix}$
#
#
# The transformation $T =
# \begin{bmatrix}
# 3 & 0 \\
# 0 & 2 \\
# \end{bmatrix}$  is applied, which sends the three vectors to the light green vector
# $\begin{bmatrix}
# 3 \\
# 0 \\
# \end{bmatrix}$, the magenta vector
# $\begin{bmatrix}
# 3 \\
# 2 \\
# \end{bmatrix}$ and the orange vector
# $\begin{bmatrix}
# 0 \\
# 2 \\
# \end{bmatrix}$, respectively.
#
#
# ![picture alt](https://i.ibb.co/HnSZBGN/Z-1t-R-Pv-Eeecp-Qo-q-ZJ4-g-c4d0e4a759d0a182d396003a5808e5d3-D.png)
#
# Which of the three original vectors are eigenvectors of the linear transformation $T$?
#
#
# **$\begin{bmatrix}
# 1 \\
# 0 \\
# \end{bmatrix}$**
#
# **$\begin{bmatrix}
# 0 \\
# 1 \\
# \end{bmatrix}$**

# %% [markdown]
# <br/>**3.**
# Recall that for a linear transformation, an eigenvector is a vector which, after applying the transformation, stays in the same span. In the following questions, you will try to geometrically see which vectors of a linear transformation are eigenvectors.
#
# In the following diagram, the dark green vector is given by
# $\begin{bmatrix}
# 1 \\
# 0 \\
# \end{bmatrix}$, the purple vector by
# $\begin{bmatrix}
# 1 \\
# 1 \\
# \end{bmatrix}$ and the brown vector by
# $\begin{bmatrix}
# 0 \\
# 1 \\
# \end{bmatrix}$
#
#
# The transformation $T =
# \begin{bmatrix}
# 1 & 2 \\
# 0 & 1 \\
# \end{bmatrix}$  is applied, which sends the three vectors to the light green vector
# $\begin{bmatrix}
# 1 \\
# 0 \\
# \end{bmatrix}$, the magenta vector
# $\begin{bmatrix}
# 3 \\
# 1 \\
# \end{bmatrix}$ and the orange vector
# $\begin{bmatrix}
# 2 \\
# 1 \\
# \end{bmatrix}$, respectively.
#
#
# ![picture alt](https://i.ibb.co/pwVmgBn/Z-1t-R-Pv-Eeecp-Qo-q-ZJ4-g-c4d0e4a759d0a182d396003a5808e5d3-D.png)
#
# Which of the three original vectors are eigenvectors of the linear transformation $T$?
#
#
# **$\begin{bmatrix}
# 1 \\
# 0 \\
# \end{bmatrix}$**

# %% [markdown]
# <br/>**4.**
# Recall that for a linear transformation, an eigenvector is a vector which, after applying the transformation, stays in the same span. In the following questions, you will try to geometrically see which vectors of a linear transformation are eigenvectors.
#
# In the following diagram, the dark green vector is given by
# $\begin{bmatrix}
# 1 \\
# 0 \\
# \end{bmatrix}$, the purple vector by
# $\begin{bmatrix}
# 1 \\
# 1 \\
# \end{bmatrix}$ and the brown vector by
# $\begin{bmatrix}
# 0 \\
# 1 \\
# \end{bmatrix}$
#
#
# The transformation $T =
# \begin{bmatrix}
# 0 & -1 \\
# 1 & 0 \\
# \end{bmatrix}$  is applied, which sends the three vectors to the light green vector
# $\begin{bmatrix}
# 0 \\
# 1 \\
# \end{bmatrix}$, the magenta vector
# $\begin{bmatrix}
# -1 \\
# 1 \\
# \end{bmatrix}$ and the orange vector
# $\begin{bmatrix}
# -1 \\
# 0 \\
# \end{bmatrix}$, respectively.
#
#
# ![picture alt](https://i.ibb.co/M62bsv5/Z-1t-R-Pv-Eeecp-Qo-q-ZJ4-g-c4d0e4a759d0a182d396003a5808e5d3-D.png)
#
# Which of the three original vectors are eigenvectors of the linear transformation $T$?
#
#
# **None of the above.**

# %% [markdown]
# <br/>**5.**
# Recall that for a linear transformation, an eigenvector is a vector which, after applying the transformation, stays in the same span. In the following questions, you will try to geometrically see which vectors of a linear transformation are eigenvectors.
#
# In the following diagram, the dark green vector is given by
# $\begin{bmatrix}
# 1 \\
# 0 \\
# \end{bmatrix}$, the purple vector by
# $\begin{bmatrix}
# 1 \\
# 1 \\
# \end{bmatrix}$ and the brown vector by
# $\begin{bmatrix}
# 0 \\
# 1 \\
# \end{bmatrix}$
#
#
# The transformation $T =
# \begin{bmatrix}
# -1 & 0 \\
# 0 & -1 \\
# \end{bmatrix}$  is applied, which sends the three vectors to the light green vector
# $\begin{bmatrix}
# -1 \\
# 0 \\
# \end{bmatrix}$, the magenta vector
# $\begin{bmatrix}
# -1 \\
# -1 \\
# \end{bmatrix}$ and the orange vector
# $\begin{bmatrix}
# 0 \\
# -1 \\
# \end{bmatrix}$, respectively.
#
#
# ![picture alt](https://i.ibb.co/jHxP6jr/Z-1t-R-Pv-Eeecp-Qo-q-ZJ4-g-c4d0e4a759d0a182d396003a5808e5d3-D.png)
#
# Which of the three original vectors are eigenvectors of the linear transformation $T$?
#
#
# **$\begin{bmatrix}
# 1 \\
# 0 \\
# \end{bmatrix}$**
#
# **$\begin{bmatrix}
# 1 \\
# 1 \\
# \end{bmatrix}$**
#
# **$\begin{bmatrix}
# 0 \\
# 1 \\
# \end{bmatrix}$**

# %% [markdown]
# <br/>**6.**
# Recall that for a linear transformation, an eigenvector is a vector which, after applying the transformation, stays in the same span. In the following questions, you will try to geometrically see which vectors of a linear transformation are eigenvectors.
#
# In the following diagram, the dark green vector is given by
# $\begin{bmatrix}
# 1 \\
# 0 \\
# \end{bmatrix}$, the purple vector by
# $\begin{bmatrix}
# 1 \\
# 1 \\
# \end{bmatrix}$ and the brown vector by
# $\begin{bmatrix}
# 0 \\
# 1 \\
# \end{bmatrix}$
#
#
# The transformation $T =
# \begin{bmatrix}
# 2 & 1 \\
# 0 & 2 \\
# \end{bmatrix}$  is applied, which sends the three vectors to the light green vector
# $\begin{bmatrix}
# -1 \\
# 0 \\
# \end{bmatrix}$, the magenta vector
# $\begin{bmatrix}
# 3 \\
# 2 \\
# \end{bmatrix}$ and the orange vector
# $\begin{bmatrix}
# 1 \\
# 2 \\
# \end{bmatrix}$, respectively.
#
#
# ![picture alt](https://i.ibb.co/h7bXVCd/Z-1t-R-Pv-Eeecp-Qo-q-ZJ4-g-c4d0e4a759d0a182d396003a5808e5d3-D.png)
#
# Which of the three original vectors are eigenvectors of the linear transformation $T$?
#
# **$\begin{bmatrix}
# 1 \\
# 0 \\
# \end{bmatrix}$**
