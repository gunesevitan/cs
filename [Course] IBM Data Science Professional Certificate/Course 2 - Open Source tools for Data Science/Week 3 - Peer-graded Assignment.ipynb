# %% [markdown]
# # My Jupyter Notebook on IBM Data Science Experience

# %% [markdown]
# **Gunes Evitan**
# Data Science

# %% [markdown]
# *I am interested in data science because it involves problem solving more extensively and it is less repetitive than other fields of programming.*

# %% [markdown]
# ### It prints the string "Hello".

# %%
print("Hello")
# Out:
# Hello

# %% [markdown]
# 1. First item of the numbered list
# 2. Second item of the numbered list
#     * First item of the bulleted list
#     * Second item of the bulleted list
#     * [Hyperlink](https://www.google.com)
#     * `print("Hello")` Code/Syntax Highlighting
